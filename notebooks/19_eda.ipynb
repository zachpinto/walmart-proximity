# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv('DISTANCE_MATRIX_API_KEY')

def fetch_and_append_distances(input_file, API_KEY):
    # Load the input data
    sample_data = pd.read_csv(input_file)

    # Temporary file to store updated data
    temp_file = input_file + '.tmp'

    # Open the temporary file for writing
    with open(temp_file, 'w') as f_out:
        # Write the header with the new 'travel_time' column
        f_out.write(','.join(sample_data.columns.tolist() + ['travel_time']) + '\n')

        # Iterate through each row in the sample data
        for index, row in sample_data.iterrows():
            origin = row['origin']
            destination = row['destination']
            
            # API request
            url = f"https://api.distancematrix.ai/maps/api/distancematrix/json?origins={origin}&destinations={destination}&key={API_KEY}"
            response = requests.get(url)
            
            # Print the response for debugging
            print(f"Response for {origin} to {destination}: {response.text}")

            # Default value for travel time in case of an error
            travel_time = 'N/A'

            if response.status_code == 200:
                data = response.json()
                if data['status'] == 'OK':
                    distance_info = data['rows'][0]['elements'][0]
                    if distance_info['status'] == 'OK':
                        travel_time = distance_info['duration']['text']

            # Append the updated row to the temporary file
            updated_row = row.tolist() + [travel_time]
            f_out.write(','.join(map(str, updated_row)) + '\n')

    # Replace the original file with the updated temporary file
    os.replace(temp_file, input_file)

# Set the path to your file and get your API key from environment variable
input_file = '/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/time_distance_sample.csv'

# Call the function to append travel time
fetch_and_append_distances(input_file, API_KEY)

print("Travel time data appended to CSV successfully.")
# Out:
# Response for 41.295893,-93.104232 to 41.687183,-93.772041: {"destination_addresses":["Grimes, Iowa, USA"],"origin_addresses":["Knoxville Township, Iowa 50138, USA"],"rows":[{"elements":[{"distance":{"text":"86.3 km","value":86335},"duration":{"text":"55 mins","value":3317},"origin":"41.295893,-93.104232","destination":"41.687183,-93.772041","status":"OK"}]}],"status":"OK"}
# Response for 38.763463,-77.186063 to 38.960109,-78.187619: {"destination_addresses":["Baby, Front Royal, VA 22630, USA"],"origin_addresses":["7112 Lamar Dr, Springfield, VA 22150, USA"],"rows":[{"elements":[{"distance":{"text":"107.1 km","value":107099},"duration":{"text":"1 hour 9 mins","value":4177},"origin":"38.763463,-77.186063","destination":"38.960109,-78.187619","status":"OK"}]}],"status":"OK"}
# Response for 44.12036,-69.24005 to 43.837601,-70.445011: {"destination_addresses":["30 Landing Rd, Windham, ME 04062, USA"],"origin_addresses":["350 Main St, Warren, ME 04864, USA"],"rows":[{"elements":[{"distance":{"text":"129 km","value":129029},"duration":{"text":"1 hour 37 mins","value":5821},"origin":"44.12036,-69.24005","destination":"43.837601,-70.445011","status":"OK"}]}],"status":"OK"}
# Response for 47.529679,-100.271687 to 48.820912,-100.439464: {"destination_addresses":["311 11th St E, Bottineau, ND 58318, USA"],"origin_addresses":["Goodrich Public School District 16, North Dakota, USA"],"rows":[{"elements":[{"distance":{"text":"176 km","value":176034},"duration":{"text":"1 hour 48 mins","value":6513},"origin":"47.529679,-100.271687","destination":"48.820912,-100.439464","status":"OK"}]}],"status":"OK"}
# Response for 43.54195,-114.31008 to 42.694082,-114.515923: {"destination_addresses":["2680 S Lincoln Ave, Jerome, ID 83338, USA"],"origin_addresses":["Blaine County School District 61, Idaho, USA"],"rows":[{"elements":[{"distance":{"text":"105.2 km","value":105151},"duration":{"text":"1 hour 15 mins","value":4530},"origin":"43.54195,-114.31008","destination":"42.694082,-114.515923","status":"OK"}]}],"status":"OK"}
# Response for 27.978147,-82.781523 to 28.477174,-81.628863: {"destination_addresses":["16313 New Independence Pkwy #800, Winter Garden, FL 34787, USA"],"origin_addresses":["1019 Pine Brook Dr, Clearwater, FL 33755, USA"],"rows":[{"elements":[{"distance":{"text":"156.7 km","value":156664},"duration":{"text":"1 hour 41 mins","value":6064},"origin":"27.978147,-82.781523","destination":"28.477174,-81.628863","status":"OK"}]}],"status":"OK"}
# Response for 39.99754,-85.74664 to 39.249364,-84.429904: {"destination_addresses":["Woodforest National Bank ATM, 2801 Cunningham Dr, Cincinnati, OH 45241, United States"],"origin_addresses":["412 S Pendleton Ave, Pendleton, IN 46064, USA"],"rows":[{"elements":[{"distance":{"text":"188.3 km","value":188274},"duration":{"text":"2 hour 3 mins","value":7403},"origin":"39.99754,-85.74664","destination":"39.249364,-84.429904","status":"OK"}]}],"status":"OK"}
# Response for 34.105281,-117.662035 to 33.655637,-117.987691: {"destination_addresses":["21190 Beach Blvd, Huntington Beach, CA 92648, USA"],"origin_addresses":["854 Orchid Ct, Upland, CA 91786, USA"],"rows":[{"elements":[{"distance":{"text":"74.7 km","value":74674},"duration":{"text":"1 hour 3 mins","value":3833},"origin":"34.105281,-117.662035","destination":"33.655637,-117.987691","status":"OK"}]}],"status":"OK"}
# Response for 44.245004,-71.888882 to 44.950484,-72.171959: {"destination_addresses":["115 Seymour Dr, Newport, VT 05855, USA"],"origin_addresses":["1389 Lyman Rd, Lisbon, NH 03585, USA"],"rows":[{"elements":[{"distance":{"text":"105.8 km","value":105823},"duration":{"text":"1 hour 8 mins","value":4125},"origin":"44.245004,-71.888882","destination":"44.950484,-72.171959","status":"OK"}]}],"status":"OK"}
# Response for 39.695488,-119.811146 to 39.422763,-119.756413: {"destination_addresses":["Primo Water Refill \u0026 Exchange, 155 Damonte Ranch Pkwy, Reno, NV 89511, United States"],"origin_addresses":["Washoe County School District, Nevada, USA"],"rows":[{"elements":[{"distance":{"text":"36.8 km","value":36840},"duration":{"text":"31 mins","value":1895},"origin":"39.695488,-119.811146","destination":"39.422763,-119.756413","status":"OK"}]}],"status":"OK"}
# Response for 38.31555,-93.327381 to 38.573574,-94.857331: {"destination_addresses":["310 Hedge Ln Rd, Paola, KS 66071, USA"],"origin_addresses":["Warsaw, Missouri 65355, USA"],"rows":[{"elements":[{"distance":{"text":"170.9 km","value":170891},"duration":{"text":"1 hour 53 mins","value":6821},"origin":"38.31555,-93.327381","destination":"38.573574,-94.857331","status":"OK"}]}],"status":"OK"}
# Response for 36.831647,-76.270561 to 37.03671,-76.403592: {"destination_addresses":["117 Marketplace Dr, Hampton, VA 23666, USA"],"origin_addresses":["796 Crosman Ave, Norfolk, VA 23523, USA"],"rows":[{"elements":[{"distance":{"text":"41.2 km","value":41216},"duration":{"text":"32 mins","value":1941},"origin":"36.831647,-76.270561","destination":"37.03671,-76.403592","status":"OK"}]}],"status":"OK"}
# Response for 41.416747,-72.906096 to 41.368419,-72.160661: {"destination_addresses":["167 Parkway N, Waterford, CT 06385, USA"],"origin_addresses":["Hamden School District, Hamden, CT, USA"],"rows":[{"elements":[{"distance":{"text":"85.9 km","value":85942},"duration":{"text":"54 mins","value":3281},"origin":"41.416747,-72.906096","destination":"41.368419,-72.160661","status":"OK"}]}],"status":"OK"}
# Response for 35.919953,-84.516642 to 36.617776,-83.703397: {"destination_addresses":["Middlesboro, Kentucky 40965, USA"],"origin_addresses":["Tennessee, United States"],"rows":[{"elements":[{"distance":{"text":"138.7 km","value":138652},"duration":{"text":"1 hour 56 mins","value":6996},"origin":"35.919953,-84.516642","destination":"36.617776,-83.703397","status":"OK"}]}],"status":"OK"}
# Response for 40.653635,-97.430884 to 41.262003,-95.933564: {"destination_addresses":["Downtown Northeast, Omaha, NE, USA"],"origin_addresses":["Exeter-Fairmont Consolidated, Nebraska, USA"],"rows":[{"elements":[{"distance":{"text":"171.4 km","value":171358},"duration":{"text":"1 hour 36 mins","value":5801},"origin":"40.653635,-97.430884","destination":"41.262003,-95.933564","status":"OK"}]}],"status":"OK"}
# Response for 37.53256,-122.247806 to 37.68997,-121.87697: {"destination_addresses":["3112 Santa Rita Rd, Pleasanton, CA 94566, USA"],"origin_addresses":["28 Admiralty Pl, Redwood City, CA 94065, USA"],"rows":[{"elements":[{"distance":{"text":"60.3 km","value":60258},"duration":{"text":"41 mins","value":2499},"origin":"37.53256,-122.247806","destination":"37.68997,-121.87697","status":"OK"}]}],"status":"OK"}
# Response for 43.612344,-96.364663 to 43.12513,-95.152458: {"destination_addresses":["500 11th St SW, Spencer, IA 51301, USA"],"origin_addresses":["211 S 3rd St, Beaver Creek, MN 56116, USA"],"rows":[{"elements":[{"distance":{"text":"157.8 km","value":157754},"duration":{"text":"1 hour 38 mins","value":5907},"origin":"43.612344,-96.364663","destination":"43.12513,-95.152458","status":"OK"}]}],"status":"OK"}
# Response for 40.897823,-77.773188 to 40.929304,-78.982898: {"destination_addresses":["KeyMe Locksmiths, 21920 US-119, Punxsutawney, PA 15767, United States"],"origin_addresses":["Centre County, Pennsylvania 16823, USA"],"rows":[{"elements":[{"distance":{"text":"137.3 km","value":137311},"duration":{"text":"1 hour 37 mins","value":5822},"origin":"40.897823,-77.773188","destination":"40.929304,-78.982898","status":"OK"}]}],"status":"OK"}
# Response for 41.53283,-85.08108 to 40.554883,-84.540796: {"destination_addresses":["Walmart Pharmacy, 1950 Havemann Rd, Celina, OH 45822, United States"],"origin_addresses":["326 N Main St, Hudson, IN 46747, USA"],"rows":[{"elements":[{"distance":{"text":"144.5 km","value":144494},"duration":{"text":"1 hour 33 mins","value":5620},"origin":"41.53283,-85.08108","destination":"40.554883,-84.540796","status":"OK"}]}],"status":"OK"}
# Response for 37.97746,-89.081507 to 38.59589,-90.506702: {"destination_addresses":["Western Union, 201 Highlands Blvd Dr, Manchester, MO 63011, United States"],"origin_addresses":["Tyrone Township, Illinois, USA"],"rows":[{"elements":[{"distance":{"text":"205.3 km","value":205321},"duration":{"text":"2 hour 1 mins","value":7282},"origin":"37.97746,-89.081507","destination":"38.59589,-90.506702","status":"OK"}]}],"status":"OK"}
# Response for 41.258201,-82.119671 to 41.157701,-81.300226: {"destination_addresses":["Rav SR59 \u0026 HVN of PRTG EB, Franklin Township, OH 44240, United States"],"origin_addresses":["Lagrange Township, Ohio, USA"],"rows":[{"elements":[{"distance":{"text":"98 km","value":97971},"duration":{"text":"1 hour 7 mins","value":4030},"origin":"41.258201,-82.119671","destination":"41.157701,-81.300226","status":"OK"}]}],"status":"OK"}
# Response for 40.3906,-91.38126 to 39.437961,-92.445983: {"destination_addresses":["820 US-24, Moberly, MO 65270, USA"],"origin_addresses":["117 S Water St, Keokuk, IA 52632, USA"],"rows":[{"elements":[{"distance":{"text":"191.7 km","value":191723},"duration":{"text":"2 hour 2 mins","value":7350},"origin":"40.3906,-91.38126","destination":"39.437961,-92.445983","status":"OK"}]}],"status":"OK"}
# Response for 41.236242,-95.041216 to 41.177653,-96.059955: {"destination_addresses":["9460 Giles Rd, La Vista, NE 68128, USA"],"origin_addresses":["Noble Township, Iowa, USA"],"rows":[{"elements":[{"distance":{"text":"92.7 km","value":92745},"duration":{"text":"1 hour 8 mins","value":4081},"origin":"41.236242,-95.041216","destination":"41.177653,-96.059955","status":"OK"}]}],"status":"OK"}
# Response for 37.193593,-92.078527 to 36.268971,-93.139001: {"destination_addresses":["Quick-Tag, Walmart Supercenter, 161 Wal Mart Dr, Harrison, AR 72601, United States"],"origin_addresses":["Cass Township, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"220.9 km","value":220936},"duration":{"text":"2 hour 15 mins","value":8108},"origin":"37.193593,-92.078527","destination":"36.268971,-93.139001","status":"OK"}]}],"status":"OK"}
# Response for 44.15117,-72.49288 to 44.950484,-72.171959: {"destination_addresses":["115 Seymour Dr, Newport, VT 05855, USA"],"origin_addresses":["4 Baptist St, Graniteville, VT 05654, USA"],"rows":[{"elements":[{"distance":{"text":"109.8 km","value":109836},"duration":{"text":"1 hour 30 mins","value":5441},"origin":"44.15117,-72.49288","destination":"44.950484,-72.171959","status":"OK"}]}],"status":"OK"}
# Response for 36.200019,-79.880028 to 35.714728,-78.843201: {"destination_addresses":["1000 S Hughes St, Apex, NC 27502, USA"],"origin_addresses":["4204-4206 Citron Dr, Summerfield, NC 27358, USA"],"rows":[{"elements":[{"distance":{"text":"145.8 km","value":145834},"duration":{"text":"1 hour 27 mins","value":5239},"origin":"36.200019,-79.880028","destination":"35.714728,-78.843201","status":"OK"}]}],"status":"OK"}
# Response for 41.616247,-80.306783 to 41.128104,-78.737404: {"destination_addresses":["Walmart House Cleaning Services, 20 Industrial Dr, DuBois, PA 15801, United States"],"origin_addresses":["Conneaut Lake, Conneaut Lakeshore, PA 16316, USA"],"rows":[{"elements":[{"distance":{"text":"185 km","value":185002},"duration":{"text":"1 hour 50 mins","value":6625},"origin":"41.616247,-80.306783","destination":"41.128104,-78.737404","status":"OK"}]}],"status":"OK"}
# Response for 33.874815,-118.240208 to 33.829541,-118.090738: {"destination_addresses":["7250 Carson Blvd, Long Beach, CA 90808, USA"],"origin_addresses":["1011 W Artesia Blvd, Compton, CA 90220, USA"],"rows":[{"elements":[{"distance":{"text":"20.5 km","value":20461},"duration":{"text":"16 mins","value":980},"origin":"33.874815,-118.240208","destination":"33.829541,-118.090738","status":"OK"}]}],"status":"OK"}
# Response for 30.583474,-97.857453 to 30.644842,-97.689481: {"destination_addresses":["622 I-35, Georgetown, TX 78628, USA"],"origin_addresses":["651 N US Hwy 183, Leander, TX 78641, USA"],"rows":[{"elements":[{"distance":{"text":"22.1 km","value":22088},"duration":{"text":"25 mins","value":1550},"origin":"30.583474,-97.857453","destination":"30.644842,-97.689481","status":"OK"}]}],"status":"OK"}
# Response for 38.49871,-80.7551 to 39.645871,-79.998579: {"destination_addresses":["Walmart Patio \u0026 Garden Services, 5605 University Town Centre Dr, Morgantown, WV 26501, United States"],"origin_addresses":["Birch River, West Virginia 26610, USA"],"rows":[{"elements":[{"distance":{"text":"171.7 km","value":171728},"duration":{"text":"1 hour 36 mins","value":5764},"origin":"38.49871,-80.7551","destination":"39.645871,-79.998579","status":"OK"}]}],"status":"OK"}
# Response for 39.18915,-108.06035 to 38.749609,-108.05355: {"destination_addresses":["Subway, 37 Stafford Ln, Delta, CO 81416, United States"],"origin_addresses":["C \u0026 D Tree Service, Molina, CO 81646, United States"],"rows":[{"elements":[{"distance":{"text":"108.5 km","value":108520},"duration":{"text":"1 hour 16 mins","value":4589},"origin":"39.18915,-108.06035","destination":"38.749609,-108.05355","status":"OK"}]}],"status":"OK"}
# Response for 37.345785,-120.42415 to 37.515581,-120.84732: {"destination_addresses":["2480 Geer Rd, Turlock, CA 95382, USA"],"origin_addresses":["Merced City Elementary School District, California, USA"],"rows":[{"elements":[{"distance":{"text":"49.4 km","value":49405},"duration":{"text":"41 mins","value":2465},"origin":"37.345785,-120.42415","destination":"37.515581,-120.84732","status":"OK"}]}],"status":"OK"}
# Response for 34.334398,-83.837912 to 34.656318,-84.488276: {"destination_addresses":["Walmart Home Services, 88 Highland Crossing, East Ellijay, GA 30540, United States"],"origin_addresses":["Gainesville, Georgia, USA"],"rows":[{"elements":[{"distance":{"text":"85 km","value":84998},"duration":{"text":"1 hour 9 mins","value":4173},"origin":"34.334398,-83.837912","destination":"34.656318,-84.488276","status":"OK"}]}],"status":"OK"}
# Response for 31.538397,-83.784347 to 32.179212,-83.180453: {"destination_addresses":["1098 Indian Dr, Eastman, GA 31023, USA"],"origin_addresses":["Worth County School District, Georgia, USA"],"rows":[{"elements":[{"distance":{"text":"106.9 km","value":106854},"duration":{"text":"1 hour 17 mins","value":4662},"origin":"31.538397,-83.784347","destination":"32.179212,-83.180453","status":"OK"}]}],"status":"OK"}
# Response for 40.78581,-96.698002 to 40.72941,-96.684676: {"destination_addresses":["2500 Jamie Ln, Lincoln, NE 68512, USA"],"origin_addresses":["Irvingdale, Lincoln, NE 68502, USA"],"rows":[{"elements":[{"distance":{"text":"7.9 km","value":7921},"duration":{"text":"11 mins","value":696},"origin":"40.78581,-96.698002","destination":"40.72941,-96.684676","status":"OK"}]}],"status":"OK"}
# Response for 42.4161,-92.2149 to 42.05207,-93.622077: {"destination_addresses":["3015 Grand Ave, Ames, IA 50010, USA"],"origin_addresses":["Blackhawk co. Shed, Gilbertville, IA 50634, United States"],"rows":[{"elements":[{"distance":{"text":"167.5 km","value":167463},"duration":{"text":"1 hour 37 mins","value":5845},"origin":"42.4161,-92.2149","destination":"42.05207,-93.622077","status":"OK"}]}],"status":"OK"}
# Response for 36.314975,-79.06404 to 35.855693,-80.06605: {"destination_addresses":["Coinstar, Wal-Mart, 1585 Liberty Dr Ste 1, Thomasville, NC 27360, United States"],"origin_addresses":["Bushy Fork Township, North Carolina, USA"],"rows":[{"elements":[{"distance":{"text":"121.5 km","value":121485},"duration":{"text":"1 hour 18 mins","value":4715},"origin":"36.314975,-79.06404","destination":"35.855693,-80.06605","status":"OK"}]}],"status":"OK"}
# Response for 47.4975,-101.37127 to 46.858098,-100.768499: {"destination_addresses":["1400 Skyline Blvd, Bismarck, ND 58503, USA"],"origin_addresses":["Riverdale, North Dakota, USA"],"rows":[{"elements":[{"distance":{"text":"102.1 km","value":102072},"duration":{"text":"1 hour 1 mins","value":3677},"origin":"47.4975,-101.37127","destination":"46.858098,-100.768499","status":"OK"}]}],"status":"OK"}
# Response for 44.470235,-88.454719 to 45.16238,-89.140861: {"destination_addresses":["Antigo, Wisconsin 54409, USA"],"origin_addresses":["Black Creek, Wisconsin 54106, USA"],"rows":[{"elements":[{"distance":{"text":"132.4 km","value":132400},"duration":{"text":"1 hour 25 mins","value":5104},"origin":"44.470235,-88.454719","destination":"45.16238,-89.140861","status":"OK"}]}],"status":"OK"}
# Response for 33.480536,-117.227005 to 33.727524,-116.268223: {"destination_addresses":["STE C305, Indio, CA 92201, USA"],"origin_addresses":["Murrieta Valley Unified School District, California, USA"],"rows":[{"elements":[{"distance":{"text":"169.7 km","value":169684},"duration":{"text":"1 hour 47 mins","value":6456},"origin":"33.480536,-117.227005","destination":"33.727524,-116.268223","status":"OK"}]}],"status":"OK"}
# Response for 39.747179,-104.991511 to 39.656102,-104.994921: {"destination_addresses":["601 Englewood Pkwy, Englewood, CO 80110, USA"],"origin_addresses":["Central Business District, Denver, CO 80299, USA"],"rows":[{"elements":[{"distance":{"text":"13.8 km","value":13762},"duration":{"text":"19 mins","value":1157},"origin":"39.747179,-104.991511","destination":"39.656102,-104.994921","status":"OK"}]}],"status":"OK"}
# Response for 34.840077,-101.5097 to 35.656235,-101.41154: {"destination_addresses":["1501 Roosevelt St, Borger, TX 79007, USA"],"origin_addresses":["Claude Independent School District, Texas, USA"],"rows":[{"elements":[{"distance":{"text":"125.4 km","value":125380},"duration":{"text":"1 hour 22 mins","value":4967},"origin":"34.840077,-101.5097","destination":"35.656235,-101.41154","status":"OK"}]}],"status":"OK"}
# Response for 37.64871,-82.1314 to 37.117083,-82.794957: {"destination_addresses":["350 Whitesburg Plaza, Whitesburg, KY 41858, USA"],"origin_addresses":["Redjacket Community Church, 126 Walgrove Cir, Matewan, WV 25678, United States"],"rows":[{"elements":[{"distance":{"text":"127.1 km","value":127131},"duration":{"text":"1 hour 34 mins","value":5686},"origin":"37.64871,-82.1314","destination":"37.117083,-82.794957","status":"OK"}]}],"status":"OK"}
# Response for 33.077371,-84.321736 to 34.037763,-84.688562: {"destination_addresses":["Acworth, Georgia, USA"],"origin_addresses":["Pike County School District, Georgia, USA"],"rows":[{"elements":[{"distance":{"text":"130.2 km","value":130213},"duration":{"text":"1 hour 46 mins","value":6375},"origin":"33.077371,-84.321736","destination":"34.037763,-84.688562","status":"OK"}]}],"status":"OK"}
# Response for 38.321125,-86.823444 to 37.754268,-87.061347: {"destination_addresses":["Western Union, 3151 Leitchfield Rd, Owensboro, KY 42303, United States"],"origin_addresses":["Jackson Township, Indiana, USA"],"rows":[{"elements":[{"distance":{"text":"83.6 km","value":83585},"duration":{"text":"56 mins","value":3365},"origin":"38.321125,-86.823444","destination":"37.754268,-87.061347","status":"OK"}]}],"status":"OK"}
# Response for 36.7394,-97.889923 to 37.644036,-98.713521: {"destination_addresses":["2003 E 1st St, Pratt, KS 67124, USA"],"origin_addresses":["Pond Creek-Hunter Schools, Oklahoma, USA"],"rows":[{"elements":[{"distance":{"text":"174.5 km","value":174523},"duration":{"text":"1 hour 50 mins","value":6645},"origin":"36.7394,-97.889923","destination":"37.644036,-98.713521","status":"OK"}]}],"status":"OK"}
# Response for 43.5758,-96.09447 to 43.472446,-96.729415: {"destination_addresses":["7821 S Minnesota Ave, Sioux Falls, SD 57108, USA"],"origin_addresses":["Kanaranzi, Minnesota 56158, USA"],"rows":[{"elements":[{"distance":{"text":"63.8 km","value":63843},"duration":{"text":"53 mins","value":3188},"origin":"43.5758,-96.09447","destination":"43.472446,-96.729415","status":"OK"}]}],"status":"OK"}
# Response for 34.43038,-85.898669 to 35.140383,-86.56815: {"destination_addresses":["1115 Huntsville Hwy, Fayetteville, TN 37334, USA"],"origin_addresses":["DeKalb County School District, Alabama, USA"],"rows":[{"elements":[{"distance":{"text":"138.1 km","value":138134},"duration":{"text":"1 hour 41 mins","value":6095},"origin":"34.43038,-85.898669","destination":"35.140383,-86.56815","status":"OK"}]}],"status":"OK"}
# Response for 37.981442,-90.041779 to 37.785686,-89.028097: {"destination_addresses":["Herrin, Illinois, USA"],"origin_addresses":["Ste. Genevieve, Missouri 63670, USA"],"rows":[{"elements":[{"distance":{"text":"117.5 km","value":117543},"duration":{"text":"1 hour 33 mins","value":5635},"origin":"37.981442,-90.041779","destination":"37.785686,-89.028097","status":"OK"}]}],"status":"OK"}
# Response for 30.069437,-94.260793 to 29.917979,-95.415585: {"destination_addresses":["10411 N Fwy Service Rd, Houston, TX 77038, USA"],"origin_addresses":["Hardin-Jefferson Independent School District, Texas, USA"],"rows":[{"elements":[{"distance":{"text":"134.7 km","value":134716},"duration":{"text":"1 hour 26 mins","value":5183},"origin":"30.069437,-94.260793","destination":"29.917979,-95.415585","status":"OK"}]}],"status":"OK"}
# Response for 41.732036,-92.512822 to 42.033367,-91.553014: {"destination_addresses":["Walmart House Cleaning Services, 5491 US-151, Marion, IA 52302, United States"],"origin_addresses":["Bear Creek Township, Iowa, USA"],"rows":[{"elements":[{"distance":{"text":"127.2 km","value":127178},"duration":{"text":"1 hour 15 mins","value":4542},"origin":"41.732036,-92.512822","destination":"42.033367,-91.553014","status":"OK"}]}],"status":"OK"}
# Response for 39.316461,-103.323143 to 38.837655,-104.769498: {"destination_addresses":["Walmart Photo Center, 3201 E Platte Ave, Colorado Springs, CO 80909, United States"],"origin_addresses":["Arriba-Flagler School District C-20, Colorado, USA"],"rows":[{"elements":[{"distance":{"text":"147.7 km","value":147677},"duration":{"text":"1 hour 38 mins","value":5898},"origin":"39.316461,-103.323143","destination":"38.837655,-104.769498","status":"OK"}]}],"status":"OK"}
# Response for 47.05221,-122.025502 to 47.16137,-122.288701: {"destination_addresses":["310 31st Ave SE, Puyallup, WA 98374, USA"],"origin_addresses":["White River School District, Washington, USA"],"rows":[{"elements":[{"distance":{"text":"39.3 km","value":39284},"duration":{"text":"46 mins","value":2791},"origin":"47.05221,-122.025502","destination":"47.16137,-122.288701","status":"OK"}]}],"status":"OK"}
# Response for 41.4987,-74.55849 to 40.883026,-74.705559: {"destination_addresses":["30 International Dr S, Flanders, NJ 07836, USA"],"origin_addresses":["5 Maple Ln, Middletown, NY 10940, USA"],"rows":[{"elements":[{"distance":{"text":"87.4 km","value":87374},"duration":{"text":"1 hour 19 mins","value":4741},"origin":"41.4987,-74.55849","destination":"40.883026,-74.705559","status":"OK"}]}],"status":"OK"}
# Response for 41.530351,-81.307472 to 41.406965,-82.65893: {"destination_addresses":["5500 Milan Rd Space 304, Sandusky, OH 44870, USA"],"origin_addresses":["Ruh Property, Chesterland, OH 44026, USA"],"rows":[{"elements":[{"distance":{"text":"134.3 km","value":134279},"duration":{"text":"1 hour 30 mins","value":5405},"origin":"41.530351,-81.307472","destination":"41.406965,-82.65893","status":"OK"}]}],"status":"OK"}
# Response for 31.441909,-100.301587 to 31.487716,-100.461136: {"destination_addresses":["SmartStyle Hair Salon, 610 W 29th St, San Angelo, TX 76903, United States"],"origin_addresses":["Veribest Independent School District, Texas, USA"],"rows":[{"elements":[{"distance":{"text":"21.6 km","value":21568},"duration":{"text":"18 mins","value":1110},"origin":"31.441909,-100.301587","destination":"31.487716,-100.461136","status":"OK"}]}],"status":"OK"}
# Response for 29.6188,-99.51531 to 29.264501,-98.549002: {"destination_addresses":["Southside, San Antonio, TX 78264, USA"],"origin_addresses":["Utopia, Texas 78884, USA"],"rows":[{"elements":[{"distance":{"text":"138.8 km","value":138772},"duration":{"text":"1 hour 39 mins","value":5955},"origin":"29.6188,-99.51531","destination":"29.264501,-98.549002","status":"OK"}]}],"status":"OK"}
# Response for 33.913678,-80.354238 to 32.853019,-79.991295: {"destination_addresses":["2613 Ferrara Dr, North Charleston, SC 29405, USA"],"origin_addresses":["230 S Purdy St, Sumter, SC 29150, USA"],"rows":[{"elements":[{"distance":{"text":"159.2 km","value":159214},"duration":{"text":"1 hour 30 mins","value":5406},"origin":"33.913678,-80.354238","destination":"32.853019,-79.991295","status":"OK"}]}],"status":"OK"}
# Response for 39.189677,-81.513911 to 38.755061,-82.927261: {"destination_addresses":["4645 Gallia St, New Boston, OH 45662, USA"],"origin_addresses":["1333 Windsor Dr, Mineral Wells, WV 26150, USA"],"rows":[{"elements":[{"distance":{"text":"174.3 km","value":174252},"duration":{"text":"2 hour 2 mins","value":7338},"origin":"39.189677,-81.513911","destination":"38.755061,-82.927261","status":"OK"}]}],"status":"OK"}
# Response for 36.220421,-91.746312 to 36.523814,-91.533636: {"destination_addresses":["Scott Cecil - State Farm Insurance Agent, 151 E Walnut St, Thayer, MO 65791, United States"],"origin_addresses":["Horseshoe Bend, Arkansas, USA"],"rows":[{"elements":[{"distance":{"text":"49 km","value":49025},"duration":{"text":"42 mins","value":2546},"origin":"36.220421,-91.746312","destination":"36.523814,-91.533636","status":"OK"}]}],"status":"OK"}
# Response for 38.117579,-86.928645 to 38.234935,-86.130676: {"destination_addresses":["Walmart CORYDON #922, 2363 IN-135, Corydon, IN 47112, United States"],"origin_addresses":["Santa Claus, Indiana, USA"],"rows":[{"elements":[{"distance":{"text":"82 km","value":82038},"duration":{"text":"49 mins","value":2992},"origin":"38.117579,-86.928645","destination":"38.234935,-86.130676","status":"OK"}]}],"status":"OK"}
# Response for 39.80461,-87.780032 to 39.818481,-88.882686: {"destination_addresses":["4625 Maryland St, Decatur, IL 62521, USA"],"origin_addresses":["Young America Township, Illinois, USA"],"rows":[{"elements":[{"distance":{"text":"97.5 km","value":97545},"duration":{"text":"1 hour 9 mins","value":4185},"origin":"39.80461,-87.780032","destination":"39.818481,-88.882686","status":"OK"}]}],"status":"OK"}
# Response for 46.125267,-123.905174 to 45.454923,-122.828051: {"destination_addresses":["9055 SW 147th Terrace, Beaverton, OR 97007, USA"],"origin_addresses":["United States"],"rows":[{"elements":[{"distance":{"text":"142 km","value":141995},"duration":{"text":"1 hour 48 mins","value":6489},"origin":"46.125267,-123.905174","destination":"45.454923,-122.828051","status":"OK"}]}],"status":"OK"}
# Response for 47.999093,-99.535801 to 48.194732,-101.299693: {"destination_addresses":["Greyhound: Bus Stop, 3900 S Broadway, Minot, ND 58701, United States"],"origin_addresses":["North Viking, North Dakota 58348, USA"],"rows":[{"elements":[{"distance":{"text":"175.8 km","value":175757},"duration":{"text":"1 hour 44 mins","value":6254},"origin":"47.999093,-99.535801","destination":"48.194732,-101.299693","status":"OK"}]}],"status":"OK"}
# Response for 46.777036,-116.525556 to 47.741678,-117.402747: {"destination_addresses":["11705 N Wilson St #15C, Olympia, WA 98513, USA"],"origin_addresses":["Whitepine Joint School District 288, Idaho, USA"],"rows":[{"elements":[{"distance":{"text":"173.6 km","value":173558},"duration":{"text":"2 hour 14 mins","value":8076},"origin":"46.777036,-116.525556","destination":"47.741678,-117.402747","status":"OK"}]}],"status":"OK"}
# Response for 39.190101,-87.547036 to 39.144852,-86.577864: {"destination_addresses":["SR 45 \u0026 Hickory Leaf, Bloomington, IN 47403, United States"],"origin_addresses":["Fairbanks Township, Indiana, USA"],"rows":[{"elements":[{"distance":{"text":"108 km","value":108017},"duration":{"text":"1 hour 24 mins","value":5097},"origin":"39.190101,-87.547036","destination":"39.144852,-86.577864","status":"OK"}]}],"status":"OK"}
# Response for 21.1925,-156.986111 to 21.39113,-158.034572: {"destination_addresses":["21.39113,-158.034572"],"origin_addresses":["21.1925,-156.986111"],"rows":[{"elements":[{"origin":"21.1925,-156.986111","destination":"21.39113,-158.034572","status":"ZERO_RESULTS"}]}],"status":"OK"}
# Response for 34.86065,-90.59233 to 34.361915,-89.565339: {"destination_addresses":["Oxford, Mississippi 38655, USA"],"origin_addresses":["Brickeys, Arkansas, USA"],"rows":[{"elements":[{"distance":{"text":"205 km","value":205034},"duration":{"text":"1 hour 59 mins","value":7198},"origin":"34.86065,-90.59233","destination":"34.361915,-89.565339","status":"OK"}]}],"status":"OK"}
# Response for 39.806991,-86.100535 to 40.281427,-86.478439: {"destination_addresses":["2460 E Wabash St, Frankfort, IN 46041, USA"],"origin_addresses":["3918 E 28th St, Indianapolis, IN 46218, USA"],"rows":[{"elements":[{"distance":{"text":"83 km","value":83022},"duration":{"text":"59 mins","value":3558},"origin":"39.806991,-86.100535","destination":"40.281427,-86.478439","status":"OK"}]}],"status":"OK"}
# Response for 43.678125,-95.171548 to 43.603284,-96.789711: {"destination_addresses":["Walmart Home Theater Installation, 5200 W 60th St N, Sioux Falls, SD 57107, United States"],"origin_addresses":["330 Main St, Lakefield, MN 56150, USA"],"rows":[{"elements":[{"distance":{"text":"137.6 km","value":137573},"duration":{"text":"1 hour 17 mins","value":4644},"origin":"43.678125,-95.171548","destination":"43.603284,-96.789711","status":"OK"}]}],"status":"OK"}
# Response for 32.926431,-82.172337 to 32.202914,-82.362555: {"destination_addresses":["SmartStyle Hair Salon, 3109 E 1st St, Vidalia, GA 30474, United States"],"origin_addresses":["Burke County School District, Georgia, USA"],"rows":[{"elements":[{"distance":{"text":"96.3 km","value":96259},"duration":{"text":"1 hour 12 mins","value":4355},"origin":"32.926431,-82.172337","destination":"32.202914,-82.362555","status":"OK"}]}],"status":"OK"}
# Response for 41.973292,-87.700351 to 42.238666,-87.951217: {"destination_addresses":["555 E Townline Rd Ste 9, Vernon Hills, IL 60061, USA"],"origin_addresses":["5036 N Mozart St, Chicago, IL 60625, USA"],"rows":[{"elements":[{"distance":{"text":"47.3 km","value":47305},"duration":{"text":"40 mins","value":2459},"origin":"41.973292,-87.700351","destination":"42.238666,-87.951217","status":"OK"}]}],"status":"OK"}
# Response for 34.907715,-87.50135 to 34.908673,-88.534974: {"destination_addresses":["Alcorn School District, Mississippi, USA"],"origin_addresses":["Lauderdale County School District, Alabama, USA"],"rows":[{"elements":[{"distance":{"text":"117.1 km","value":117109},"duration":{"text":"1 hour 26 mins","value":5179},"origin":"34.907715,-87.50135","destination":"34.908673,-88.534974","status":"OK"}]}],"status":"OK"}
# Response for 45.59179,-120.69811 to 46.255889,-119.307921: {"destination_addresses":["Walmart House Cleaning Services, 2801 Duportail St, Richland, WA 99352, United States"],"origin_addresses":["710-700 OR-206, Wasco, OR 97065, USA"],"rows":[{"elements":[{"distance":{"text":"206.6 km","value":206566},"duration":{"text":"1 hour 57 mins","value":7063},"origin":"45.59179,-120.69811","destination":"46.255889,-119.307921","status":"OK"}]}],"status":"OK"}
# Response for 46.886152,-95.724599 to 47.495427,-94.908745: {"destination_addresses":["2025 Paul Bunyan Dr NW, Bemidji, MN 56601, USA"],"origin_addresses":["Erie Township, Minnesota, USA"],"rows":[{"elements":[{"distance":{"text":"134.4 km","value":134387},"duration":{"text":"1 hour 29 mins","value":5374},"origin":"46.886152,-95.724599","destination":"47.495427,-94.908745","status":"OK"}]}],"status":"OK"}
# Response for 44.52913,-90.88931 to 44.35456,-89.814112: {"destination_addresses":["Coinstar, Wal-Mart, 4331 8th St S, Wisconsin Rapids, WI 54494, United States"],"origin_addresses":["N3024 King St, Humbird, WI 54746, USA"],"rows":[{"elements":[{"distance":{"text":"107.4 km","value":107428},"duration":{"text":"1 hour 18 mins","value":4703},"origin":"44.52913,-90.88931","destination":"44.35456,-89.814112","status":"OK"}]}],"status":"OK"}
# Response for 48.293181,-117.739245 to 47.70409,-117.030861: {"destination_addresses":["6405 W Pointe Pkwy, Post Falls, ID 83854, USA"],"origin_addresses":["Chewelah School District, Washington, USA"],"rows":[{"elements":[{"distance":{"text":"103.3 km","value":103276},"duration":{"text":"1 hour 18 mins","value":4704},"origin":"48.293181,-117.739245","destination":"47.70409,-117.030861","status":"OK"}]}],"status":"OK"}
# Response for 40.647049,-123.913353 to 41.77284,-124.194649: {"destination_addresses":["Sutter Coast Hospital, California 95531, United States"],"origin_addresses":["Eureka City Unified School District (9-12), California, USA"],"rows":[{"elements":[{"distance":{"text":"168.8 km","value":168792},"duration":{"text":"2 hour 26 mins","value":8817},"origin":"40.647049,-123.913353","destination":"41.77284,-124.194649","status":"OK"}]}],"status":"OK"}
# Response for 40.418367,-82.283974 to 40.328134,-83.757797: {"destination_addresses":["2281 S United States Rte 68, Bellefontaine, OH 43311, USA"],"origin_addresses":["Howard Township, Ohio, USA"],"rows":[{"elements":[{"distance":{"text":"163.3 km","value":163256},"duration":{"text":"1 hour 50 mins","value":6637},"origin":"40.418367,-82.283974","destination":"40.328134,-83.757797","status":"OK"}]}],"status":"OK"}
# Response for 39.267855,-94.472963 to 39.020347,-95.648552: {"destination_addresses":["2630 SE California Ave, Topeka, KS 66605, USA"],"origin_addresses":["Liberty Township, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"125.1 km","value":125119},"duration":{"text":"1 hour 12 mins","value":4334},"origin":"39.267855,-94.472963","destination":"39.020347,-95.648552","status":"OK"}]}],"status":"OK"}
# Response for 42.61837,-77.737515 to 42.767208,-78.128128: {"destination_addresses":["2348 NY-19, Warsaw, NY 14569, USA"],"origin_addresses":["West Sparta, New York, USA"],"rows":[{"elements":[{"distance":{"text":"45.1 km","value":45111},"duration":{"text":"40 mins","value":2457},"origin":"42.61837,-77.737515","destination":"42.767208,-78.128128","status":"OK"}]}],"status":"OK"}
# Response for 34.598755,-79.707693 to 35.59435,-78.780868: {"destination_addresses":["1051 E Broad St, Fuquay-Varina, NC 27526, USA"],"origin_addresses":["Marlboro County, South Carolina, USA"],"rows":[{"elements":[{"distance":{"text":"180.8 km","value":180805},"duration":{"text":"2 hour 6 mins","value":7603},"origin":"34.598755,-79.707693","destination":"35.59435,-78.780868","status":"OK"}]}],"status":"OK"}
# Response for 39.62732,-104.779035 to 40.422969,-104.753585: {"destination_addresses":["Greeley, Colorado 80634, USA"],"origin_addresses":["17901 E Grand Ave, Aurora, CO 80015, USA"],"rows":[{"elements":[{"distance":{"text":"110.5 km","value":110460},"duration":{"text":"1 hour 22 mins","value":4924},"origin":"39.62732,-104.779035","destination":"40.422969,-104.753585","status":"OK"}]}],"status":"OK"}
# Response for 35.87563,-89.39618 to 36.355073,-88.883587: {"destination_addresses":["134 Courtright Rd, Martin, TN 38237, USA"],"origin_addresses":["109 N Church St, Halls, TN 38040, USA"],"rows":[{"elements":[{"distance":{"text":"95.4 km","value":95379},"duration":{"text":"1 hour 4 mins","value":3870},"origin":"35.87563,-89.39618","destination":"36.355073,-88.883587","status":"OK"}]}],"status":"OK"}
# Response for 35.149223,-84.874031 to 34.29393,-83.850851: {"destination_addresses":["Gainesville, Georgia, USA"],"origin_addresses":["1175 Blythe Ave SE, Cleveland, TN 37311, USA"],"rows":[{"elements":[{"distance":{"text":"173.4 km","value":173388},"duration":{"text":"2 hour 19 mins","value":8383},"origin":"35.149223,-84.874031","destination":"34.29393,-83.850851","status":"OK"}]}],"status":"OK"}
# Response for 34.811726,-82.331435 to 34.861405,-82.681301: {"destination_addresses":["Pickens County School District, South Carolina, USA"],"origin_addresses":["Greenville, South Carolina, USA"],"rows":[{"elements":[{"distance":{"text":"40.3 km","value":40332},"duration":{"text":"36 mins","value":2160},"origin":"34.811726,-82.331435","destination":"34.861405,-82.681301","status":"OK"}]}],"status":"OK"}
# Response for 47.139095,-122.258646 to 47.624833,-122.632657: {"destination_addresses":["6797 WA-303, Bremerton, WA 98311, USA"],"origin_addresses":["12806-12820 129th St E, South Hill, WA 98374, USA"],"rows":[{"elements":[{"distance":{"text":"96.6 km","value":96596},"duration":{"text":"1 hour 7 mins","value":4053},"origin":"47.139095,-122.258646","destination":"47.624833,-122.632657","status":"OK"}]}],"status":"OK"}
# Response for 43.783229,-94.713525 to 44.32867,-94.505377: {"destination_addresses":["Elizabeth Kampa, 1720 Westridge Rd, New Ulm, MN 560732337, United States"],"origin_addresses":["Galena Township, Minnesota, USA"],"rows":[{"elements":[{"distance":{"text":"75.2 km","value":75237},"duration":{"text":"53 mins","value":3237},"origin":"43.783229,-94.713525","destination":"44.32867,-94.505377","status":"OK"}]}],"status":"OK"}
# Response for 42.297229,-78.649654 to 43.192244,-77.497393: {"destination_addresses":["Walmart Supercenter, 1990 Brandt Point Dr, Webster, NY 14580, United States"],"origin_addresses":["6861 Horn Hill Rd, Ellicottville, NY 14731, USA"],"rows":[{"elements":[{"distance":{"text":"169.1 km","value":169141},"duration":{"text":"2 hour 0 mins","value":7242},"origin":"42.297229,-78.649654","destination":"43.192244,-77.497393","status":"OK"}]}],"status":"OK"}
# Response for 33.178426,-81.182699 to 32.950186,-80.155167: {"destination_addresses":["Western Union, 9880 Dorchester Rd, Summerville, SC 29485, United States"],"origin_addresses":["52 Myrtle Ave, Olar, SC 29843, USA"],"rows":[{"elements":[{"distance":{"text":"111.2 km","value":111166},"duration":{"text":"1 hour 24 mins","value":5091},"origin":"33.178426,-81.182699","destination":"32.950186,-80.155167","status":"OK"}]}],"status":"OK"}
# Response for 37.41839,-95.68026 to 38.582125,-95.267201: {"destination_addresses":["2121 S Princeton St, Ottawa, KS 66067, USA"],"origin_addresses":["Neodesha City Muni Airport, RR 2, Neodesha, KS 66757, United States"],"rows":[{"elements":[{"distance":{"text":"157.1 km","value":157069},"duration":{"text":"1 hour 38 mins","value":5897},"origin":"37.41839,-95.68026","destination":"38.582125,-95.267201","status":"OK"}]}],"status":"OK"}
# Response for 40.69648,-76.16883 to 40.714554,-75.281048: {"destination_addresses":["Walmart Baby \u0026 Nursery Services, 3722 Nazareth Rd, Easton, PA 18045, United States"],"origin_addresses":["110 Lawton St, Port Carbon, PA 17965, USA"],"rows":[{"elements":[{"distance":{"text":"99.9 km","value":99921},"duration":{"text":"1 hour 13 mins","value":4411},"origin":"40.69648,-76.16883","destination":"40.714554,-75.281048","status":"OK"}]}],"status":"OK"}
# Response for 47.209445,-122.227319 to 47.507986,-122.631246: {"destination_addresses":["1653 SE Sylvis Ln, Port Orchard, WA 98366, USA"],"origin_addresses":["5217 151st Ave Ct E, Sumner, WA 98390, USA"],"rows":[{"elements":[{"distance":{"text":"59.3 km","value":59305},"duration":{"text":"46 mins","value":2786},"origin":"47.209445,-122.227319","destination":"47.507986,-122.631246","status":"OK"}]}],"status":"OK"}
# Response for 33.362613,-95.104664 to 33.134364,-94.96521: {"destination_addresses":["Coinstar, Wal-Mart, 2311 S Jefferson Ave, Mt Pleasant, TX 75455, United States"],"origin_addresses":["Midway Cemetery, 2584 County Road NE #3110, Talco, TX 75487, United States"],"rows":[{"elements":[{"distance":{"text":"31 km","value":30967},"duration":{"text":"24 mins","value":1480},"origin":"33.362613,-95.104664","destination":"33.134364,-94.96521","status":"OK"}]}],"status":"OK"}
# Response for 43.248825,-97.538733 to 42.531713,-96.374643: {"destination_addresses":["Walmart Connection Center, 3101 Floyd Blvd, Sioux City, IA 51108, United States"],"origin_addresses":["433rd Ave, Menno, SD 57045, USA"],"rows":[{"elements":[{"distance":{"text":"170.6 km","value":170601},"duration":{"text":"1 hour 40 mins","value":6038},"origin":"43.248825,-97.538733","destination":"42.531713,-96.374643","status":"OK"}]}],"status":"OK"}
# Response for 43.00586,-84.37164 to 43.489595,-83.973978: {"destination_addresses":["Saginaw, Michigan 48604, USA"],"origin_addresses":["100-130 N Main St, Ovid, MI 48866, USA"],"rows":[{"elements":[{"distance":{"text":"85 km","value":84968},"duration":{"text":"1 hour 8 mins","value":4113},"origin":"43.00586,-84.37164","destination":"43.489595,-83.973978","status":"OK"}]}],"status":"OK"}
# Response for 40.38865,-85.49942 to 39.661539,-86.145198: {"destination_addresses":["7187-7119 US 31 S, Indianapolis, IN 46227, USA"],"origin_addresses":["W 7th St, Matthews, IN 46957, USA"],"rows":[{"elements":[{"distance":{"text":"132.1 km","value":132078},"duration":{"text":"1 hour 20 mins","value":4821},"origin":"40.38865,-85.49942","destination":"39.661539,-86.145198","status":"OK"}]}],"status":"OK"}
# Response for 39.30403,-104.756722 to 40.405703,-105.044725: {"destination_addresses":["1337-1301 N Denver Ave, Loveland, CO 80537, USA"],"origin_addresses":["Douglas County, Colorado, USA"],"rows":[{"elements":[{"distance":{"text":"149 km","value":148969},"duration":{"text":"1 hour 35 mins","value":5710},"origin":"39.30403,-104.756722","destination":"40.405703,-105.044725","status":"OK"}]}],"status":"OK"}
# Response for 40.777387,-79.233585 to 40.600959,-79.19361: {"destination_addresses":["Plaza Rd, Indiana, PA 15701, USA"],"origin_addresses":["1461 State Rte 1042, Numine, PA 16244, USA"],"rows":[{"elements":[{"distance":{"text":"31.9 km","value":31861},"duration":{"text":"24 mins","value":1464},"origin":"40.777387,-79.233585","destination":"40.600959,-79.19361","status":"OK"}]}],"status":"OK"}
# Response for 40.042115,-116.974803 to 40.840442,-115.792789: {"destination_addresses":["MoneyGram, 2944 Mountain City Hwy, Elko, NV 89801, United States"],"origin_addresses":["Lander County School District, Nevada, USA"],"rows":[{"elements":[{"distance":{"text":"156.8 km","value":156816},"duration":{"text":"2 hour 10 mins","value":7820},"origin":"40.042115,-116.974803","destination":"40.840442,-115.792789","status":"OK"}]}],"status":"OK"}
# Response for 41.040507,-81.194614 to 41.382942,-81.743944: {"destination_addresses":["8036 Day Dr, Parma, OH 44129, USA"],"origin_addresses":["Atwater Township, Ohio, USA"],"rows":[{"elements":[{"distance":{"text":"80.4 km","value":80424},"duration":{"text":"1 hour 4 mins","value":3895},"origin":"41.040507,-81.194614","destination":"41.382942,-81.743944","status":"OK"}]}],"status":"OK"}
# Response for 41.43349,-81.632298 to 41.309765,-81.518643: {"destination_addresses":["ATM Wal-mart, Macedonia, OH 44056, United States"],"origin_addresses":["7709 Avondale Ave, Garfield Heights, OH 44125, USA"],"rows":[{"elements":[{"distance":{"text":"23.7 km","value":23698},"duration":{"text":"21 mins","value":1311},"origin":"41.43349,-81.632298","destination":"41.309765,-81.518643","status":"OK"}]}],"status":"OK"}
# Response for 30.547365,-88.708582 to 30.332079,-89.187336: {"destination_addresses":["Pass Christian, Mississippi 39571, USA"],"origin_addresses":["Vancleave, Mississippi 39565, USA"],"rows":[{"elements":[{"distance":{"text":"71.1 km","value":71113},"duration":{"text":"51 mins","value":3065},"origin":"30.547365,-88.708582","destination":"30.332079,-89.187336","status":"OK"}]}],"status":"OK"}
# Response for 47.551771,-122.144727 to 47.507986,-122.631246: {"destination_addresses":["1653 SE Sylvis Ln, Port Orchard, WA 98366, USA"],"origin_addresses":["14635 SE 56th St, Bellevue, WA 98006, USA"],"rows":[{"elements":[{"distance":{"text":"95.2 km","value":95164},"duration":{"text":"1 hour 4 mins","value":3879},"origin":"47.551771,-122.144727","destination":"47.507986,-122.631246","status":"OK"}]}],"status":"OK"}
# Response for 44.294793,-96.270936 to 44.296139,-94.707251: {"destination_addresses":["1201 Main St E, Sleepy Eye, MN 56085, USA"],"origin_addresses":["Diamond Lake Township, Minnesota, USA"],"rows":[{"elements":[{"distance":{"text":"135.3 km","value":135309},"duration":{"text":"1 hour 38 mins","value":5890},"origin":"44.294793,-96.270936","destination":"44.296139,-94.707251","status":"OK"}]}],"status":"OK"}
# Response for 38.835412,-77.063959 to 38.327269,-75.615103: {"destination_addresses":["TNT Fireworks, 409 N Fruitland Blvd, Salisbury, MD 21804, United States"],"origin_addresses":["230 Burgess Ave, Alexandria, VA 22305, USA"],"rows":[{"elements":[{"distance":{"text":"203.2 km","value":203174},"duration":{"text":"2 hour 25 mins","value":8705},"origin":"38.835412,-77.063959","destination":"38.327269,-75.615103","status":"OK"}]}],"status":"OK"}
# Response for 43.417126,-89.070459 to 43.489272,-88.811505: {"destination_addresses":["Walmart House Cleaning Services, 120 Frances Ln, Beaver Dam, WI 53916, United States"],"origin_addresses":["Fountain Prairie, Wisconsin, USA"],"rows":[{"elements":[{"distance":{"text":"31.4 km","value":31420},"duration":{"text":"24 mins","value":1454},"origin":"43.417126,-89.070459","destination":"43.489272,-88.811505","status":"OK"}]}],"status":"OK"}
# Response for 44.94858,-90.5643 to 45.635859,-89.383313: {"destination_addresses":["Walmart Home Services, 2121 Lincoln St, Rhinelander, WI 54501, United States"],"origin_addresses":["Usda Soil Conservation Services, RR 2, Owen, WI 54460, United States"],"rows":[{"elements":[{"distance":{"text":"169.8 km","value":169801},"duration":{"text":"1 hour 43 mins","value":6204},"origin":"44.94858,-90.5643","destination":"45.635859,-89.383313","status":"OK"}]}],"status":"OK"}
# Response for 42.31259,-72.20786 to 41.641973,-71.007903: {"destination_addresses":["506 State Rd, North Dartmouth, MA 02747, USA"],"origin_addresses":["67 North St #73, Gilbertville, MA 01031, USA"],"rows":[{"elements":[{"distance":{"text":"148.4 km","value":148397},"duration":{"text":"1 hour 52 mins","value":6772},"origin":"42.31259,-72.20786","destination":"41.641973,-71.007903","status":"OK"}]}],"status":"OK"}
# Response for 38.978405,-79.949417 to 37.811926,-80.429334: {"destination_addresses":["1242 US-219, Lewisburg, WV 24901, USA"],"origin_addresses":["14-22 US-250, Belington, WV 26250, USA"],"rows":[{"elements":[{"distance":{"text":"183.6 km","value":183566},"duration":{"text":"2 hour 34 mins","value":9247},"origin":"38.978405,-79.949417","destination":"37.811926,-80.429334","status":"OK"}]}],"status":"OK"}
# Response for 39.188663,-98.044605 to 38.023657,-97.338544: {"destination_addresses":["Coinstar, Wal-Mart, 1701 S Kansas Ave, Newton, KS 67114, United States"],"origin_addresses":["229 White St, Barnard, KS 67418, USA"],"rows":[{"elements":[{"distance":{"text":"175.5 km","value":175472},"duration":{"text":"1 hour 41 mins","value":6113},"origin":"39.188663,-98.044605","destination":"38.023657,-97.338544","status":"OK"}]}],"status":"OK"}
# Response for 43.062016,-76.134145 to 42.157069,-76.854158: {"destination_addresses":["1400 County Rd 64, Horseheads, NY 14845, USA"],"origin_addresses":["321 Highland Ave, Syracuse, NY 13203, USA"],"rows":[{"elements":[{"distance":{"text":"141.6 km","value":141553},"duration":{"text":"1 hour 49 mins","value":6568},"origin":"43.062016,-76.134145","destination":"42.157069,-76.854158","status":"OK"}]}],"status":"OK"}
# Response for 40.46254,-92.01684 to 39.437961,-92.445983: {"destination_addresses":["820 US-24, Moberly, MO 65270, USA"],"origin_addresses":["Brad Wittstock and Family, RR1 Box 1A, Arbela, MO 63432, United States"],"rows":[{"elements":[{"distance":{"text":"165.4 km","value":165402},"duration":{"text":"1 hour 47 mins","value":6474},"origin":"40.46254,-92.01684","destination":"39.437961,-92.445983","status":"OK"}]}],"status":"OK"}
# Response for 43.034725,-98.315504 to 43.516781,-96.773492: {"destination_addresses":["Walmart Patio \u0026 Garden Services, 3209 S Louise Ave, Sioux Falls, SD 57106, United States"],"origin_addresses":["Lawrence Township, South Dakota 57380, USA"],"rows":[{"elements":[{"distance":{"text":"180 km","value":179984},"duration":{"text":"1 hour 51 mins","value":6692},"origin":"43.034725,-98.315504","destination":"43.516781,-96.773492","status":"OK"}]}],"status":"OK"}
# ...
# Response for 29.529062,-95.530597 to 29.458533,-96.938246: {"destination_addresses":["1506 N Texana St, Hallettsville, TX 77964, USA"],"origin_addresses":["Missouri City, Texas, USA"],"rows":[{"elements":[{"distance":{"text":"151 km","value":151016},"duration":{"text":"1 hour 43 mins","value":6210},"origin":"29.529062,-95.530597","destination":"29.458533,-96.938246","status":"OK"}]}],"status":"OK"}
# Response for 35.608108,-80.144554 to 36.071699,-79.498885: {"destination_addresses":["FedEx Office Print \u0026 Ship Center, 3141 Garden Rd, Burlington, NC 27215, United States"],"origin_addresses":["Healing Spring Township, North Carolina, USA"],"rows":[{"elements":[{"distance":{"text":"93 km","value":92971},"duration":{"text":"1 hour 2 mins","value":3735},"origin":"35.608108,-80.144554","destination":"36.071699,-79.498885","status":"OK"}]}],"status":"OK"}
# Response for 41.4662,-74.19126 to 40.98991,-75.18291: {"destination_addresses":["Jackson Hewitt Tax Service, 355 Lincoln Ave, East Stroudsburg, PA 18301, United States"],"origin_addresses":["12-14 Forrester Rd, Rock Tavern, NY 12575, USA"],"rows":[{"elements":[{"distance":{"text":"117.1 km","value":117120},"duration":{"text":"1 hour 38 mins","value":5908},"origin":"41.4662,-74.19126","destination":"40.98991,-75.18291","status":"OK"}]}],"status":"OK"}
# Response for 43.75358,-96.07252 to 43.603284,-96.789711: {"destination_addresses":["Walmart Home Theater Installation, 5200 W 60th St N, Sioux Falls, SD 57107, United States"],"origin_addresses":["294 200th Ave, Kenneth, MN 56147, USA"],"rows":[{"elements":[{"distance":{"text":"73.1 km","value":73066},"duration":{"text":"44 mins","value":2656},"origin":"43.75358,-96.07252","destination":"43.603284,-96.789711","status":"OK"}]}],"status":"OK"}
# Response for 35.62389,-98.912212 to 35.421606,-97.528106: {"destination_addresses":["4420 S Western Ave, Oklahoma City, OK 73109, USA"],"origin_addresses":["Thomas-Fay-Custer Unified Schools, Oklahoma, USA"],"rows":[{"elements":[{"distance":{"text":"145.3 km","value":145256},"duration":{"text":"1 hour 30 mins","value":5448},"origin":"35.62389,-98.912212","destination":"35.421606,-97.528106","status":"OK"}]}],"status":"OK"}
# Response for 40.866096,-86.233899 to 41.669946,-85.898023: {"destination_addresses":["Concord Community Schools, Indiana, USA"],"origin_addresses":["Adams Township, Indiana, USA"],"rows":[{"elements":[{"distance":{"text":"125.6 km","value":125598},"duration":{"text":"1 hour 20 mins","value":4836},"origin":"40.866096,-86.233899","destination":"41.669946,-85.898023","status":"OK"}]}],"status":"OK"}
# Response for 34.488104,-99.158545 to 33.950386,-98.525959: {"destination_addresses":["2646-2602 Central E Fwy, Wichita Falls, TX 76306, USA"],"origin_addresses":["Tipton Public Schools, Oklahoma, USA"],"rows":[{"elements":[{"distance":{"text":"112.4 km","value":112385},"duration":{"text":"1 hour 9 mins","value":4176},"origin":"34.488104,-99.158545","destination":"33.950386,-98.525959","status":"OK"}]}],"status":"OK"}
# Response for 35.156145,-76.632264 to 34.80114,-77.415432: {"destination_addresses":["4250 Western Blvd, Jacksonville, NC 28546, USA"],"origin_addresses":["Pamlico County, North Carolina, USA"],"rows":[{"elements":[{"distance":{"text":"110.3 km","value":110333},"duration":{"text":"1 hour 15 mins","value":4520},"origin":"35.156145,-76.632264","destination":"34.80114,-77.415432","status":"OK"}]}],"status":"OK"}
# Response for 43.728235,-71.335248 to 43.033993,-70.788875: {"destination_addresses":["Men's Wear, Portsmouth, NH 03801, USA"],"origin_addresses":["Moultonborough, New Hampshire 03254, USA"],"rows":[{"elements":[{"distance":{"text":"106.5 km","value":106543},"duration":{"text":"1 hour 16 mins","value":4588},"origin":"43.728235,-71.335248","destination":"43.033993,-70.788875","status":"OK"}]}],"status":"OK"}
# Response for 39.208696,-104.070186 to 38.837655,-104.769498: {"destination_addresses":["Walmart Photo Center, 3201 E Platte Ave, Colorado Springs, CO 80909, United States"],"origin_addresses":["Big Sandy School District 100J, Colorado, USA"],"rows":[{"elements":[{"distance":{"text":"81.5 km","value":81451},"duration":{"text":"58 mins","value":3492},"origin":"39.208696,-104.070186","destination":"38.837655,-104.769498","status":"OK"}]}],"status":"OK"}
# Response for 38.980781,-91.127211 to 39.437961,-92.445983: {"destination_addresses":["820 US-24, Moberly, MO 65270, USA"],"origin_addresses":["Hawk Point Township, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"182.7 km","value":182689},"duration":{"text":"1 hour 45 mins","value":6304},"origin":"38.980781,-91.127211","destination":"39.437961,-92.445983","status":"OK"}]}],"status":"OK"}
# Response for 32.862105,-97.250808 to 33.034239,-96.593782: {"destination_addresses":["1400 McCreary Rd, Wylie, TX 75098, USA"],"origin_addresses":["6024 Deborah Ln, Watauga, TX 76148, USA"],"rows":[{"elements":[{"distance":{"text":"83 km","value":82997},"duration":{"text":"59 mins","value":3591},"origin":"32.862105,-97.250808","destination":"33.034239,-96.593782","status":"OK"}]}],"status":"OK"}
# Response for 29.278188,-94.83329 to 29.72298,-95.465213: {"destination_addresses":["Walmart Grocery Pickup and Delivery, 5405 S Rice Ave, Houston, TX 77081, United States"],"origin_addresses":["Galveston, Texas 77551, USA"],"rows":[{"elements":[{"distance":{"text":"89 km","value":89026},"duration":{"text":"58 mins","value":3536},"origin":"29.278188,-94.83329","destination":"29.72298,-95.465213","status":"OK"}]}],"status":"OK"}
# Response for 44.346783,-123.325952 to 44.58565,-123.257091: {"destination_addresses":["1810 NW 9th St, Corvallis, OR 97330, USA"],"origin_addresses":["Monroe School District 1J, Oregon, USA"],"rows":[{"elements":[{"distance":{"text":"30.8 km","value":30792},"duration":{"text":"29 mins","value":1762},"origin":"44.346783,-123.325952","destination":"44.58565,-123.257091","status":"OK"}]}],"status":"OK"}
# Response for 37.886012,-112.791568 to 37.172602,-113.364525: {"destination_addresses":["180 N 3400 W, Hurricane, UT 84737, USA"],"origin_addresses":["Iron County, Utah, USA"],"rows":[{"elements":[{"distance":{"text":"116.3 km","value":116342},"duration":{"text":"1 hour 7 mins","value":4068},"origin":"37.886012,-112.791568","destination":"37.172602,-113.364525","status":"OK"}]}],"status":"OK"}
# Response for 41.56867,-79.4081 to 40.475388,-78.751246: {"destination_addresses":["300 Walmart Dr, Ebensburg, PA 15931, USA"],"origin_addresses":["West Hickory, Pennsylvania 16370, USA"],"rows":[{"elements":[{"distance":{"text":"176.4 km","value":176392},"duration":{"text":"2 hour 20 mins","value":8446},"origin":"41.56867,-79.4081","destination":"40.475388,-78.751246","status":"OK"}]}],"status":"OK"}
# Response for 37.54346,-80.68257 to 37.354076,-79.18557: {"destination_addresses":["3900 Wards Rd, Lynchburg, VA 24502, USA"],"origin_addresses":["13 Main St, Greenville, WV 24945, USA"],"rows":[{"elements":[{"distance":{"text":"224.1 km","value":224051},"duration":{"text":"2 hour 38 mins","value":9518},"origin":"37.54346,-80.68257","destination":"37.354076,-79.18557","status":"OK"}]}],"status":"OK"}
# Response for 39.638988,-92.46581 to 40.215006,-92.582222: {"destination_addresses":["Kirksville, Missouri 63501, USA"],"origin_addresses":["Narrows Township, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"70.3 km","value":70306},"duration":{"text":"45 mins","value":2736},"origin":"39.638988,-92.46581","destination":"40.215006,-92.582222","status":"OK"}]}],"status":"OK"}
# Response for 30.886367,-102.890491 to 31.408739,-103.488377: {"destination_addresses":["1903 S Cedar St, Pecos, TX 79772, USA"],"origin_addresses":["1100 W 2nd St, Fort Stockton, TX 79735, USA"],"rows":[{"elements":[{"distance":{"text":"83.4 km","value":83390},"duration":{"text":"51 mins","value":3096},"origin":"30.886367,-102.890491","destination":"31.408739,-103.488377","status":"OK"}]}],"status":"OK"}
# Response for 33.938108,-118.285706 to 33.999448,-117.720431: {"destination_addresses":["3801 Grand Ave, Chino, CA 91710, USA"],"origin_addresses":["624 W 108th St, Los Angeles, CA 90044, USA"],"rows":[{"elements":[{"distance":{"text":"66.2 km","value":66238},"duration":{"text":"45 mins","value":2731},"origin":"33.938108,-118.285706","destination":"33.999448,-117.720431","status":"OK"}]}],"status":"OK"}
# Response for 39.740612,-92.644013 to 38.956973,-92.382477: {"destination_addresses":["3101 W Broadway Suite 103, Columbia, MO 65203, USA"],"origin_addresses":["Callao Township, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"115.3 km","value":115303},"duration":{"text":"1 hour 14 mins","value":4446},"origin":"39.740612,-92.644013","destination":"38.956973,-92.382477","status":"OK"}]}],"status":"OK"}
# Response for 36.824646,-90.12135 to 35.816009,-90.733916: {"destination_addresses":["1911 W Parker Rd #555, Jonesboro, AR 72404, USA"],"origin_addresses":["Dexter R-XI School District, Missouri, USA"],"rows":[{"elements":[{"distance":{"text":"188.1 km","value":188071},"duration":{"text":"2 hour 2 mins","value":7366},"origin":"36.824646,-90.12135","destination":"35.816009,-90.733916","status":"OK"}]}],"status":"OK"}
# Response for 33.928202,-117.809353 to 33.815338,-116.488056: {"destination_addresses":["5601 Ramon Rd, Palm Springs, CA 92264, USA"],"origin_addresses":["Brea, California, USA"],"rows":[{"elements":[{"distance":{"text":"148 km","value":148032},"duration":{"text":"1 hour 39 mins","value":5963},"origin":"33.928202,-117.809353","destination":"33.815338,-116.488056","status":"OK"}]}],"status":"OK"}
# Response for 42.918107,-78.865857 to 42.908748,-78.743013: {"destination_addresses":["2500 Walden Ave Suite 1, Cheektowaga, NY 14225, USA"],"origin_addresses":["577 Linwood Ave, Buffalo, NY 14209, USA"],"rows":[{"elements":[{"distance":{"text":"14.2 km","value":14220},"duration":{"text":"16 mins","value":976},"origin":"42.918107,-78.865857","destination":"42.908748,-78.743013","status":"OK"}]}],"status":"OK"}
# Response for 40.323272,-106.944274 to 39.627675,-106.500457: {"destination_addresses":["Walmart Supercenter, 171 Yoder Ave, Avon, CO 81620, United States"],"origin_addresses":["South Routt School District RE-3, Colorado, USA"],"rows":[{"elements":[{"distance":{"text":"114.3 km","value":114266},"duration":{"text":"1 hour 25 mins","value":5100},"origin":"40.323272,-106.944274","destination":"39.627675,-106.500457","status":"OK"}]}],"status":"OK"}
# Response for 39.281504,-77.025362 to 38.697238,-77.789935: {"destination_addresses":["700 James Madison Hwy, Warrenton, VA 20186, USA"],"origin_addresses":["Glenwood, Maryland, USA"],"rows":[{"elements":[{"distance":{"text":"122.2 km","value":122212},"duration":{"text":"1 hour 26 mins","value":5188},"origin":"39.281504,-77.025362","destination":"38.697238,-77.789935","status":"OK"}]}],"status":"OK"}
# Response for 40.67893,-91.07292 to 41.783172,-91.127279: {"destination_addresses":["1126 IA-38, Tipton, IA 52772, USA"],"origin_addresses":["1047-1001 IL-96, Lomax, IL 61454, USA"],"rows":[{"elements":[{"distance":{"text":"141.2 km","value":141235},"duration":{"text":"1 hour 37 mins","value":5874},"origin":"40.67893,-91.07292","destination":"41.783172,-91.127279","status":"OK"}]}],"status":"OK"}
# Response for 43.321384,-97.547869 to 43.516781,-96.773492: {"destination_addresses":["Walmart Patio \u0026 Garden Services, 3209 S Louise Ave, Sioux Falls, SD 57106, United States"],"origin_addresses":["Kassel Township, South Dakota, USA"],"rows":[{"elements":[{"distance":{"text":"85.9 km","value":85949},"duration":{"text":"1 hour 2 mins","value":3751},"origin":"43.321384,-97.547869","destination":"43.516781,-96.773492","status":"OK"}]}],"status":"OK"}
# Response for 39.080411,-84.453991 to 39.091861,-84.270019: {"destination_addresses":["KeyMe Locksmiths, 4370 Eastgate Square Dr, Cincinnati, OH 45245, United States"],"origin_addresses":["Mayfield Ave, Fort Thomas, KY 41075, USA"],"rows":[{"elements":[{"distance":{"text":"26.7 km","value":26654},"duration":{"text":"22 mins","value":1374},"origin":"39.080411,-84.453991","destination":"39.091861,-84.270019","status":"OK"}]}],"status":"OK"}
# Response for 42.266638,-83.849042 to 42.913043,-83.979358: {"destination_addresses":["506 E Genesee St, Durand, MI 48429, USA"],"origin_addresses":["Lakewood, Ann Arbor, MI 48103, USA"],"rows":[{"elements":[{"distance":{"text":"103.7 km","value":103749},"duration":{"text":"1 hour 5 mins","value":3926},"origin":"42.266638,-83.849042","destination":"42.913043,-83.979358","status":"OK"}]}],"status":"OK"}
# Response for 40.79282,-90.77986 to 40.592511,-90.035369: {"destination_addresses":["Coinstar, Wal-Mart, 2071 N. Main Street, Canton, IL 61520, United States"],"origin_addresses":["Smithshire, Illinois 61478, USA"],"rows":[{"elements":[{"distance":{"text":"83 km","value":82959},"duration":{"text":"59 mins","value":3577},"origin":"40.79282,-90.77986","destination":"40.592511,-90.035369","status":"OK"}]}],"status":"OK"}
# Response for 26.348293,-80.117265 to 26.007522,-80.20495: {"destination_addresses":["301 S State Rd 7, Hollywood, FL 33023, USA"],"origin_addresses":["Boca Raton, Florida, USA"],"rows":[{"elements":[{"distance":{"text":"44.3 km","value":44313},"duration":{"text":"33 mins","value":2017},"origin":"26.348293,-80.117265","destination":"26.007522,-80.20495","status":"OK"}]}],"status":"OK"}
# Response for 41.080474,-73.930179 to 40.714554,-75.281048: {"destination_addresses":["Walmart Baby \u0026 Nursery Services, 3722 Nazareth Rd, Easton, PA 18045, United States"],"origin_addresses":["50 Tweed Blvd, Nyack, NY 10960, USA"],"rows":[{"elements":[{"distance":{"text":"167.8 km","value":167792},"duration":{"text":"1 hour 41 mins","value":6093},"origin":"41.080474,-73.930179","destination":"40.714554,-75.281048","status":"OK"}]}],"status":"OK"}
# Response for 37.87715,-122.17969 to 37.688028,-122.130538: {"destination_addresses":["Floresta Gardens - Bradrick, San Leandro, CA, USA"],"origin_addresses":["80 Moraga Way, Orinda, CA 94563, USA"],"rows":[{"elements":[{"distance":{"text":"32.4 km","value":32389},"duration":{"text":"22 mins","value":1361},"origin":"37.87715,-122.17969","destination":"37.688028,-122.130538","status":"OK"}]}],"status":"OK"}
# Response for 42.37314,-73.36761 to 41.745546,-72.16826: {"destination_addresses":["473 Boston Post Rd, North Windham, CT 06256, USA"],"origin_addresses":["Pittsfield School District in Richmond (9-12), Richmond, MA, USA"],"rows":[{"elements":[{"distance":{"text":"175.1 km","value":175075},"duration":{"text":"1 hour 50 mins","value":6619},"origin":"42.37314,-73.36761","destination":"41.745546,-72.16826","status":"OK"}]}],"status":"OK"}
# Response for 37.688601,-76.361585 to 36.912713,-76.252393: {"destination_addresses":["Woodforest National Bank, 7530 Tidewater Dr, Norfolk, VA 23505, United States"],"origin_addresses":["3, Virginia, USA"],"rows":[{"elements":[{"distance":{"text":"117.9 km","value":117881},"duration":{"text":"1 hour 35 mins","value":5709},"origin":"37.688601,-76.361585","destination":"36.912713,-76.252393","status":"OK"}]}],"status":"OK"}
# Response for 35.347928,-84.534548 to 34.746127,-85.273067: {"destination_addresses":["Walmart Supercenter, 2625 US Hwy 27, LaFayette, GA 30728, United States"],"origin_addresses":["McMinn County School District, Tennessee, USA"],"rows":[{"elements":[{"distance":{"text":"118.1 km","value":118072},"duration":{"text":"1 hour 28 mins","value":5307},"origin":"35.347928,-84.534548","destination":"34.746127,-85.273067","status":"OK"}]}],"status":"OK"}
# Travel time data appended to CSV successfully.

# %%
# Function to convert travel time to minutes
def convert_to_minutes(time_str):
    if pd.isna(time_str) or 'min' not in time_str:
        return None
    time_parts = time_str.split()
    minutes = 0
    if 'hour' in time_str or 'hours' in time_str:
        minutes += int(time_parts[0]) * 60
        if len(time_parts) > 2:
            minutes += int(time_parts[2])
    else:
        minutes = int(time_parts[0])
    return minutes

# Process the CSV file
input_file = '/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/time_distance_sample.csv'
output_file = '/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/cleaned_time_distance_sample.csv'

with open(input_file, 'r') as f_in, open(output_file, 'w') as f_out:
    first_line = True
    for line in f_in:
        parts = line.strip().split(',')
        # Skip header or incorrect lines
        if first_line or len(parts) < 7:
            first_line = False
            continue
        origin = f'"{parts[0]},{parts[1]}"'
        destination = f'"{parts[2]},{parts[3]}"'
        ruca = parts[4]
        distance = parts[5]
        travel_time = convert_to_minutes(parts[6])
        f_out.write(f'{origin},{destination},{ruca},{distance},{travel_time}\n')

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
import pandas as pd
import json

# Function to convert kilometers to miles
def km_to_miles(km):
    return km * 0.621371

# Load the CSV data
csv_data = pd.read_csv('/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/cleaned_time_distance_sample.csv')

# Initialize a dictionary to store distance data
distance_data = {}

# Read and parse the JSON file
with open('/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/raw_api_output_distance_matrix.json', 'r') as file:
    for line in file:
        if 'Response for' in line and ':' in line:
            try:
                # Extract JSON part and response coordinates from the line
                response_prefix, json_str = line.split(': ', 1)
                json_data = json.loads(json_str)
                response_coords = response_prefix.split('Response for ')[1]
                origin_response, destination_response = response_coords.split(' to ')

                # Check if distance data is available
                if 'distance' in json_data['rows'][0]['elements'][0]:
                    distance_km = json_data['rows'][0]['elements'][0]['distance']['value'] / 1000
                    key = (origin_response, destination_response)
                    distance_data[key] = distance_km
            except json.JSONDecodeError:
                continue

# Check and create the 'distance' column if not exists
if 'distance' not in csv_data.columns:
    csv_data['distance'] = None

# Iterate over the CSV data and update distances
for index, row in csv_data.iterrows():
    origin_csv = row['origin']
    destination_csv = row['destination']
    csv_key = (origin_csv, destination_csv)

    if csv_key in distance_data:
        distance_miles = km_to_miles(distance_data[csv_key])
        csv_data.at[index, 'distance'] = distance_miles

# Save the updated CSV
csv_data.to_csv('/Users/pintoza/Desktop/dev/data-science/walmart-proximity/data/processed/final_cleaned_time_distance_sample.csv', index=False)
